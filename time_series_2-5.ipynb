# %% [markdown]
# <a href="https://colab.research.google.com/github/lalit-kumr/time_series/blob/main/time_series_2-5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Time series analysis in python

# %% [markdown]
# ## What is Time Series analysis?
#
# Time series forecasting is a technique for the prediction of events indexed by time. This techniques predict future events by analyzing the trends of the past, on the assumption that future trends will hold similar to historical trends.
#
#
# #### Time series forecasting is performed in a variety of applications including
#
# -  Weather forecasting
# -  Earthquake prediction
# -  Astronomy
# -  Statistics
# -  Finance
#
#
#
# #### There are two main goals of time series analysis:
# - identifying the nature of the phenomenon.
# - forecasting the future values of the time series variable.
#
# Both of these goals require that the pattern the time series data is identified and decomposed in its components. Once the pattern is established, we can interpret and then extrapolate it to predict future events.
#
#
# ## Stages in Time Series Forecasting
#
# The main steps of solving a time series problem are as follows:
#
# - **0. Importing the data and necessary modules**
#
# - **1. Visualizing time series**
#
#  - In this step, we try to visualize the series. We try to identify all the underlying patterns related to the series like trend and seasonality. Do not worry about these terms right now, as we will discuss them during implementation. You can say that this is more a type of exploratory analysis of time series data.
#
#
# - **2. Stationarising time series**
#
#  - `A stationary time series is one whose statistical properties such as mean, variance, autocorrelation, etc. are all constant over time.`
#   - Most statistical forecasting methods are based on the assumption that the time series is stationary. We can make a time series into a stationairy time series by applying mathematical transformations to it.A stationary time series has a constant mean, median std deviaiton across its whole time period.
#
#
# - **3. Applying ARIMA to our series and  finding the best parameters for our model**
#
#  - We need to find optimal parameters for the forecasting models once we have a stationary series. These parameters come from the ACF and PACF plots. Hence, this stage is more about plotting ACF and PACF graphs and finding optimal model parameters based on them.
#
#
# - **4. Fitting model**
#
#  - Once we have our optimal model parameters, we can fit an ARIMA model to learn the pattern of the series.
#
#
# - **5. Predictions**
#
#  - After fitting our model, we will be predicting the future in this stage. Since we are now familiar with a basic flow of solving a time series problem, let us get to the implementation.

# %% [markdown]
# ##  **0. Importing the data,cleaning it and necessary libraries**

# %%
# !pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-1.8.2-cp37-cp37m-manylinux1_x86_64.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 5.2 MB/s
# Requirement already satisfied: numpy~=1.19.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.19.5)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (57.4.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.4.1)
# Collecting statsmodels!=0.12.0,>=0.11
#   Downloading statsmodels-0.12.2-cp37-cp37m-manylinux1_x86_64.whl (9.5 MB)
#      |████████████████████████████████| 9.5 MB 45.3 MB/s
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.1.5)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.29.24)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.0.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.1)
# Installing collected packages: statsmodels, pmdarima
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# Successfully installed pmdarima-1.8.2 statsmodels-0.12.2

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import statsmodels as sm
import matplotlib.pyplot as plt
# plt.style.use('fivethirtyeight') # special style template for matplotlib, highly useful for visualizing time series data
from pylab import rcParams
rcParams['figure.figsize'] = 13, 7
# %matplotlib inline

# %%
#importing the dataset
df = pd.read_csv('https://github.com/lalit-kumr/demand-estimation-case-study/raw/main/Electricity%20Consumption.csv')

# %%
df.isna().sum()
# No blank values
# Out:
# DATE                            0
# Electricty_Consumption_in_TW    0
# dtype: int64

# %%
df.columns = ['date','electricity']
df.date = pd.to_datetime(df.date)
df.set_index('date',inplace=True)
df
# Out:
#             electricity
# date
# 1973-01-01      35.9728
# 1973-02-01      36.1334
# 1973-03-01      35.0625
# 1973-04-01      33.8416
# 1973-05-01      33.5107
# ...                 ...
# 2019-05-01      97.5860
# 2019-06-01     110.8580
# 2019-07-01     122.1014
# 2019-08-01     121.7765
# 2019-09-01     109.7190
#
# [561 rows x 1 columns]

# %% [markdown]
# ## **1. Visualizing the time series**

# %%
df.plot(figsize=(13,7))
# as we can see the line plot of the electricity consumption  has 2 main components:
#   - uptrend
#   - seasonal component

# %% [markdown]
# #### **Decomposing a Time series:**
# - A time series consists of 4 components:
#     - Trend
#     - Seasonality
#     - Cyclicity
#     - Noise
#
# **Trend**: Trend is the overall incresase or decrease overtime in a time series. It can be positive in nature(called uptrend) or negative in nature(downtrend). It can be of linear, log or any other form.
#
# **Seasonality**: The repeating short-term cycle in the series are called seasons. Usually we take seasons as phenomena that repeat yearly.
#
# **Cyclicity** : Cyclicity refers to long term patterns that occur on a scale of multiple years to decades. for exapmle the US is said to have recovered from the 2008 downturn  in 2016. so this overall change in its GDP will come under cyclicity part.
#
# **Noise**: The random variation in the series.
#
# In order to perform a time series analysis we need to seperate trend, seasons, cyclicity and noise from our series. The resultant series will become stationary through this process.
#
# So let us decompose our time series

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decompose = seasonal_decompose(df,model='multiplicative')
decompose.trend.plot(title='trend',figsize=(11,3))
decompose.seasonal.plot(title='sesonal',figsize=(11,3))
decompose.resid.plot(title='residual',figsize=(11,3))

# %% [markdown]
# ## **2. Stationarising the time series**

# %% [markdown]
# Now we need to stationarize the time series. For this we use the ADFuller test.
#
# #### 2.1 ADF (Augmented Dickey-Fuller) Test
#
# The Dickey-Fuller test is a statistical tests used to determine the presence of unit root in the series, and hence help us understand if the series is stationary or not. The null and alternate hypothesis of this test are:
#
#
# **Null Hypothesis:** The series has a unit root (value of a =1) i.e series is non-stationary and has a time dependent structure.
#
#
# **Alternate Hypothesis:** The series has no unit root.series is stationary
#
#
# If we fail to reject the null hypothesis, we can say that the series is non-stationary.

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(x):
  adfuller_result = adfuller(x)
  adf_value = adfuller_result[0]
  p_value   = adfuller_result[1]
  no_of_lags= adfuller_result[2]
  no_of_obs = adfuller_result[3]
  print('----------------adfuller_result-----------------------------')
  print('adf_value      = ',adf_value)
  print('p_value        = ',p_value   )
  print('no_of_lags     = ',no_of_lags)
  print('no_of_obs      = ',no_of_obs )
  for key, value in adfuller_result[4].items():
      print('Critial Values = ',f'{key}, {value}')
  print('-------------------------------------------------------------')



adf_test(df.electricity)
# as the adf_value is greater than 5% critical value and the p-value os greater than 0.05,
# thus the series is NON-STATIONARY
# Out:
# ----------------adfuller_result-----------------------------
# adf_value      =  -1.7405933729832606
# p_value        =  0.41032816044685966
# no_of_lags     =  15
# no_of_obs      =  545
# Critial Values =  1%, -3.442405720052601
# Critial Values =  5%, -2.866857804790472
# Critial Values =  10%, -2.5696022094099824
# -------------------------------------------------------------

# %% [markdown]
# ### 2.2 Stationarizing the time series and testing adf again

# %%
#we will first try to difference the series with its own past values(lags) and try to stationarize it.
df_lag  = df - df.shift(1)
df_lag.dropna(inplace=True)
df_lag.plot(figsize=(12,4), title='plot of df_lag')

# %%
#checking stationarity for df_lag
adf_test(df_lag.electricity)

# Now as our adf value(-7.941) is less than critical value 5%(-2.866) 
# AND our p_value(3.3013e-12) is less than 0.05, thus
# df_lag is STATIONARY IN NATURE
# Out:
# ----------------adfuller_result-----------------------------
# adf_value      =  -7.94166536398118
# p_value        =  3.301343802151508e-12
# no_of_lags     =  14
# no_of_obs      =  545
# Critial Values =  1%, -3.442405720052601
# Critial Values =  5%, -2.866857804790472
# Critial Values =  10%, -2.5696022094099824
# -------------------------------------------------------------

# %% [markdown]
# ## **3. ACF and PACF plots**
#  - To apply ARIMA to our series we have to plot acf and pacf plot for our series first.
#  - ACF: this is a graph of the correlation of the seires with its own lags. we start with lag 1 and increase the lags as needed. then we plot the correlation of the seies with its lagged version. this tell us about the trend, seasonal and cyclic component of the series
#
#  - PACF: The partial correlation between two variables is the amount of correlation between them which is not explained by their mutual correlations with a specified set of other variables. For example, if we are regressing a variable Y on other variables X1, X2, and X3, the partial correlation between Y and X3 is the amount of correlation between Y and X3 that is not explained by their common correlations with X1 and X2.
#
#  - ARIMA(p,d,q) contains p,d,q values. these values are established by:
#   - p - by acf plot
#   - q - pacf plot
#   - d - difference of time series

# %%
#acf plot
from statsmodels.graphics import tsaplots
tsaplots.plot_acf(df_lag.electricity,lags=30)

# we will take p = 1.

# %%
#pacf plot

tsaplots.plot_pacf(df_lag.electricity,lags=30)

# we will take q  = 1

# %% [markdown]
# ## **3. Applying ARIMA to our series and  finding the best parameters for our model**
# ARIMA - Arima is a time series models that contains 3 parts.
# - AR - auto regressive - p
# - I - integrated - d
# - MA - Moving average - q

# %% [markdown]
# ### 3.1 Applying ARIMA to our series

# %%
from statsmodels.tsa.arima_model import ARIMA
# 1,1,1 ARIMA Model
model = ARIMA(df.electricity, order=(1,1,1))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:          D.electricity   No. Observations:                  560
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -1777.687
# Method:                       css-mle   S.D. of innovations              5.778
# Date:                Mon, 30 Aug 2021   AIC                           3563.374
# Time:                        05:34:31   BIC                           3580.686
# Sample:                    02-01-1973   HQIC                          3570.134
#                          - 09-01-2019
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.1234      0.018      6.858      0.000       0.088       0.159
# ar.L1.D.electricity     0.6227      0.035     17.663      0.000       0.554       0.692
# ma.L1.D.electricity    -0.9741      0.008   -121.031      0.000      -0.990      -0.958
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.6060           +0.0000j            1.6060            0.0000
# MA.1            1.0266           +0.0000j            1.0266            0.0000
# -----------------------------------------------------------------------------

# %% [markdown]
# ### 3.2 Plotting residual errors

# %%
# plotting the residual errors
residuals = pd.DataFrame(model_fit.resid)
fig, ax = plt.subplots(1,2,figsize=(15,5))
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %%
#The mean of residuals is 0.02. which is slightly to the right but under the error range
np.mean(residuals)
# Out:
# 0    0.027797
# dtype: float64

# %% [markdown]
# ### 3.3 Plotting predictions

# %%
# Actual vs Fitted
model_fit.plot_predict()


# The dynamic keyword affects in-sample prediction. 
# If dynamic is False, then the in-sample lagged values are used for prediction.
# If dynamic is True, then in-sample forecasts are used in place of lagged dependent variables.

# %% [markdown]
# ## **4. Using auto arima**

# %% [markdown]
# ### 4.1 Finding best values for arima model
# Using auto arima we will now find the best p,d,q values for our time series assuming NO seasonality.

# %%
from statsmodels.tsa.arima_model import ARIMA
import pmdarima as pm

# %%
# finding the best p,d,q values for our sereis 
model_arima = pm.auto_arima(df.electricity,
                            trace=True,
                            error_action='ignore',
                            suppress_warnings=True, 
                            stepwise=True
                            )

print(model_arima.summary())


#the best values for arima are => p,d,q = (2, 1, 3)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=2828.097, Time=1.18 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3661.148, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3548.129, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=3425.666, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3659.390, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=3274.599, Time=0.49 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=3010.981, Time=0.42 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.43 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=1.49 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=3420.808, Time=0.23 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=3195.328, Time=0.51 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=3034.088, Time=0.38 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=2832.337, Time=1.84 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=2827.247, Time=0.74 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=3291.831, Time=0.15 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=3032.072, Time=0.16 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=2819.434, Time=0.99 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=3033.994, Time=0.19 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=inf, Time=1.25 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=inf, Time=1.60 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=2817.926, Time=1.06 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=3212.499, Time=0.23 sec
#  ARIMA(2,1,4)(0,0,0)[0]             : AIC=2854.730, Time=0.78 sec
#  ARIMA(1,1,4)(0,0,0)[0]             : AIC=3168.508, Time=0.39 sec
#  ARIMA(3,1,4)(0,0,0)[0]             : AIC=inf, Time=1.92 sec
#
# Best model:  ARIMA(2,1,3)(0,0,0)[0]
# Total fit time: 17.768 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  561
# Model:               SARIMAX(2, 1, 3)   Log Likelihood               -1402.963
# Date:                Mon, 30 Aug 2021   AIC                           2817.926
# Time:                        07:42:08   BIC                           2843.894
# Sample:                             0   HQIC                          2828.066
#                                 - 561
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9981      0.001    700.165      0.000       0.995       1.001
# ar.L2         -0.9995      0.001  -1224.172      0.000      -1.001      -0.998
# ma.L1         -0.7877      0.038    -20.800      0.000      -0.862      -0.713
# ma.L2          0.8314      0.034     24.494      0.000       0.765       0.898
# ma.L3          0.1479      0.037      3.984      0.000       0.075       0.221
# sigma2         8.6477      0.421     20.529      0.000       7.822       9.473
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                72.10
# Prob(Q):                              0.89   Prob(JB):                         0.00
# Heteroskedasticity (H):               8.14   Skew:                            -0.07
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.75
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### 4.2 Finding best p,d,q for sarima model

# %%
model_sarima = pm.auto_arima(df.electricity,
                      trace=True,
                      start_p=0,
                      start_q=0,
                      seasonal=True,
                      m=12)
print(model_sarima.summary())



#Best model:  ARIMA(5,1,1)(1,0,1)[12]
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=2384.557, Time=1.22 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=3661.148, Time=0.03 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=inf, Time=0.70 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=3094.486, Time=0.82 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=3659.390, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=3215.004, Time=0.38 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=inf, Time=0.55 sec
#  ARIMA(0,1,0)(2,0,1)[12] intercept   : AIC=2385.754, Time=4.16 sec
#  ARIMA(0,1,0)(1,0,2)[12] intercept   : AIC=2388.656, Time=7.11 sec
#  ARIMA(0,1,0)(0,0,2)[12] intercept   : AIC=2997.380, Time=1.59 sec
#  ARIMA(0,1,0)(2,0,0)[12] intercept   : AIC=inf, Time=2.26 sec
#  ARIMA(0,1,0)(2,0,2)[12] intercept   : AIC=inf, Time=3.93 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=2380.960, Time=1.61 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=3157.570, Time=0.59 sec
#  ARIMA(1,1,0)(2,0,1)[12] intercept   : AIC=2382.247, Time=5.08 sec
#  ARIMA(1,1,0)(1,0,2)[12] intercept   : AIC=inf, Time=6.09 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=3548.129, Time=0.09 sec
#  ARIMA(1,1,0)(0,0,2)[12] intercept   : AIC=2979.966, Time=1.67 sec
#  ARIMA(1,1,0)(2,0,0)[12] intercept   : AIC=inf, Time=2.36 sec
#  ARIMA(1,1,0)(2,0,2)[12] intercept   : AIC=inf, Time=7.53 sec
#  ARIMA(2,1,0)(1,0,1)[12] intercept   : AIC=2349.062, Time=1.84 sec
#  ARIMA(2,1,0)(0,0,1)[12] intercept   : AIC=2957.718, Time=0.82 sec
#  ARIMA(2,1,0)(1,0,0)[12] intercept   : AIC=inf, Time=1.05 sec
#  ARIMA(2,1,0)(2,0,1)[12] intercept   : AIC=2349.211, Time=5.56 sec
#  ARIMA(2,1,0)(1,0,2)[12] intercept   : AIC=inf, Time=8.25 sec
#  ARIMA(2,1,0)(0,0,0)[12] intercept   : AIC=3172.019, Time=0.17 sec
#  ARIMA(2,1,0)(0,0,2)[12] intercept   : AIC=2867.924, Time=2.09 sec
#  ARIMA(2,1,0)(2,0,0)[12] intercept   : AIC=inf, Time=3.10 sec
#  ARIMA(2,1,0)(2,0,2)[12] intercept   : AIC=2348.740, Time=9.42 sec
#  ARIMA(3,1,0)(2,0,2)[12] intercept   : AIC=2345.245, Time=9.48 sec
#  ARIMA(3,1,0)(1,0,2)[12] intercept   : AIC=inf, Time=10.22 sec
#  ARIMA(3,1,0)(2,0,1)[12] intercept   : AIC=2346.038, Time=5.16 sec
#  ARIMA(3,1,0)(1,0,1)[12] intercept   : AIC=2345.575, Time=2.16 sec
#  ARIMA(4,1,0)(2,0,2)[12] intercept   : AIC=2327.572, Time=11.45 sec
#  ARIMA(4,1,0)(1,0,2)[12] intercept   : AIC=inf, Time=8.39 sec
#  ARIMA(4,1,0)(2,0,1)[12] intercept   : AIC=2326.354, Time=8.45 sec
#  ARIMA(4,1,0)(1,0,1)[12] intercept   : AIC=2325.842, Time=2.56 sec
#  ARIMA(4,1,0)(0,0,1)[12] intercept   : AIC=2801.713, Time=1.16 sec
#  ARIMA(4,1,0)(1,0,0)[12] intercept   : AIC=inf, Time=2.00 sec
#  ARIMA(4,1,0)(0,0,0)[12] intercept   : AIC=3027.860, Time=0.36 sec
#  ARIMA(4,1,0)(0,0,2)[12] intercept   : AIC=2711.389, Time=3.28 sec
#  ARIMA(4,1,0)(2,0,0)[12] intercept   : AIC=inf, Time=5.38 sec
#  ARIMA(5,1,0)(1,0,1)[12] intercept   : AIC=2317.526, Time=3.14 sec
#  ARIMA(5,1,0)(0,0,1)[12] intercept   : AIC=2801.337, Time=1.29 sec
#  ARIMA(5,1,0)(1,0,0)[12] intercept   : AIC=inf, Time=2.39 sec
#  ARIMA(5,1,0)(2,0,1)[12] intercept   : AIC=2318.157, Time=9.56 sec
#  ARIMA(5,1,0)(1,0,2)[12] intercept   : AIC=inf, Time=9.69 sec
#  ARIMA(5,1,0)(0,0,0)[12] intercept   : AIC=3010.660, Time=0.53 sec
#  ARIMA(5,1,0)(0,0,2)[12] intercept   : AIC=2712.275, Time=3.83 sec
#  ARIMA(5,1,0)(2,0,0)[12] intercept   : AIC=inf, Time=6.82 sec
#  ARIMA(5,1,0)(2,0,2)[12] intercept   : AIC=2317.448, Time=12.70 sec
#  ARIMA(5,1,1)(2,0,2)[12] intercept   : AIC=inf, Time=13.55 sec
#  ARIMA(4,1,1)(2,0,2)[12] intercept   : AIC=inf, Time=12.78 sec
#  ARIMA(5,1,0)(2,0,2)[12]             : AIC=2315.372, Time=10.33 sec
#  ARIMA(5,1,0)(1,0,2)[12]             : AIC=2315.565, Time=8.57 sec
#  ARIMA(5,1,0)(2,0,1)[12]             : AIC=2316.200, Time=5.04 sec
#  ARIMA(5,1,0)(1,0,1)[12]             : AIC=2315.568, Time=2.00 sec
#  ARIMA(4,1,0)(2,0,2)[12]             : AIC=2324.295, Time=10.73 sec
#  ARIMA(5,1,1)(2,0,2)[12]             : AIC=2294.952, Time=11.83 sec
#  ARIMA(5,1,1)(1,0,2)[12]             : AIC=2314.923, Time=15.07 sec
#  ARIMA(5,1,1)(2,0,1)[12]             : AIC=2294.613, Time=7.33 sec
#  ARIMA(5,1,1)(1,0,1)[12]             : AIC=2294.075, Time=3.16 sec
#  ARIMA(5,1,1)(0,0,1)[12]             : AIC=2802.055, Time=1.30 sec
#  ARIMA(5,1,1)(1,0,0)[12]             : AIC=2447.748, Time=2.14 sec
#  ARIMA(5,1,1)(0,0,0)[12]             : AIC=3012.126, Time=0.46 sec
#  ARIMA(5,1,1)(0,0,2)[12]             : AIC=2712.861, Time=2.90 sec
#  ARIMA(5,1,1)(2,0,0)[12]             : AIC=2376.448, Time=5.70 sec
#  ARIMA(4,1,1)(1,0,1)[12]             : AIC=2294.315, Time=2.34 sec
#  ARIMA(5,1,2)(1,0,1)[12]             : AIC=2295.699, Time=4.20 sec
#  ARIMA(4,1,0)(1,0,1)[12]             : AIC=2323.877, Time=1.63 sec
#  ARIMA(4,1,2)(1,0,1)[12]             : AIC=inf, Time=3.97 sec
#  ARIMA(5,1,1)(1,0,1)[12] intercept   : AIC=2298.498, Time=5.25 sec
#
# Best model:  ARIMA(5,1,1)(1,0,1)[12]
# Total fit time: 330.536 seconds
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  561
# Model:             SARIMAX(5, 1, 1)x(1, 0, 1, 12)   Log Likelihood               -1138.037
# Date:                            Mon, 30 Aug 2021   AIC                           2294.075
# Time:                                    07:03:03   BIC                           2333.026
# Sample:                                         0   HQIC                          2309.284
#                                             - 561
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6970      0.043     16.083      0.000       0.612       0.782
# ar.L2         -0.1710      0.047     -3.617      0.000      -0.264      -0.078
# ar.L3          0.1017      0.051      1.999      0.046       0.002       0.201
# ar.L4         -0.0931      0.051     -1.832      0.067      -0.193       0.007
# ar.L5          0.0705      0.041      1.709      0.088      -0.010       0.151
# ma.L1         -0.9387      0.024    -39.035      0.000      -0.986      -0.892
# ar.S.L12       0.9948      0.004    280.900      0.000       0.988       1.002
# ma.S.L12      -0.6946      0.035    -20.059      0.000      -0.762      -0.627
# sigma2         3.2025      0.174     18.426      0.000       2.862       3.543
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                25.45
# Prob(Q):                              0.90   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.68   Skew:                             0.07
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.04
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### 4.3 Splitting data in train and test

# %%
train

# %%
#spitting our data into train and test
train = df.iloc[:400,:]
print('train.shape :',train.shape)
test = df.iloc[401:,:]
print('test.shape :',test.shape)
# Out:
# train.shape : (400, 1)
# test.shape : (160, 1)

# %% [markdown]
# ## 5. Training the models with the new p,d,q values

# %% [markdown]
# ### 5.1 Training the arima model and predicting the test values

# %%
model_arima = ARIMA(train,order=(1,1,3))
model_arima_fitted = model_arima.fit()

print(model_arima_fitted.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:          D.electricity   No. Observations:                  399
# Model:                 ARIMA(1, 1, 3)   Log Likelihood               -1032.237
# Method:                       css-mle   S.D. of innovations              3.194
# Date:                Mon, 30 Aug 2021   AIC                           2076.473
# Time:                        08:36:12   BIC                           2100.407
# Sample:                    02-01-1973   HQIC                          2085.952
#                          - 04-01-2006
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.1516      0.005     32.508      0.000       0.142       0.161
# ar.L1.D.electricity     0.2354      0.065      3.608      0.000       0.108       0.363
# ma.L1.D.electricity     0.0300      0.050      0.606      0.544      -0.067       0.127
# ma.L2.D.electricity    -0.4604      0.047     -9.812      0.000      -0.552      -0.368
# ma.L3.D.electricity    -0.5696      0.056    -10.089      0.000      -0.680      -0.459
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            4.2485           +0.0000j            4.2485            0.0000
# MA.1            1.0000           -0.0000j            1.0000           -0.0000
# MA.2           -0.9042           -0.9686j            1.3250           -0.3695
# MA.3           -0.9042           +0.9686j            1.3250            0.3695
# -----------------------------------------------------------------------------

# %%
#forecasting values for the test dataset
arima_test_forecast ,arima_test_stderror,arima_test_confidence_int = model_arima_fitted.forecast(steps=160,alpha=0.05)

#making the test forecast series into dataframes
arima_test_forecast = pd.DataFrame(arima_test_forecast,index= test.index)
arima_test_stderror = pd.DataFrame(arima_test_stderror,index= test.index)
arima_test_confidence_int = pd.DataFrame(arima_test_confidence_int,index= test.index)

# %%
plt.figure(figsize=(15,5))
plt.plot(train,label='train_values')
plt.plot(test,label='arima_test_values')
plt.plot(arima_test_forecast,label='forecast')
plt.fill_between(x=test_confidence_int.index,
                 y1=test_confidence_int[0],
                 y2=test_confidence_int[1],
                 color='lightgrey',
                 label='Confidence_interval 95%'
                 )
plt.legend()

# %% [markdown]
# ### 5.2 Training the SARIMA model and forecasting the test values

# %%
# training the arima model With seasonality = SARIMA

print(model_sarima.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  561
# Model:             SARIMAX(5, 1, 1)x(1, 0, 1, 12)   Log Likelihood               -1138.037
# Date:                            Mon, 30 Aug 2021   AIC                           2294.075
# Time:                                    09:08:02   BIC                           2333.026
# Sample:                                         0   HQIC                          2309.284
#                                             - 561
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6970      0.043     16.083      0.000       0.612       0.782
# ar.L2         -0.1710      0.047     -3.617      0.000      -0.264      -0.078
# ar.L3          0.1017      0.051      1.999      0.046       0.002       0.201
# ar.L4         -0.0931      0.051     -1.832      0.067      -0.193       0.007
# ar.L5          0.0705      0.041      1.709      0.088      -0.010       0.151
# ma.L1         -0.9387      0.024    -39.035      0.000      -0.986      -0.892
# ar.S.L12       0.9948      0.004    280.900      0.000       0.988       1.002
# ma.S.L12      -0.6946      0.035    -20.059      0.000      -0.762      -0.627
# sigma2         3.2025      0.174     18.426      0.000       2.862       3.543
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                25.45
# Prob(Q):                              0.90   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.68   Skew:                             0.07
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.04
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
#forecasting values for the test dataset
sarima_test_forecast , sarima_test_stderror, sarima_test_confidence_int = model_sarima.predict(steps=160,alpha=0.05)


sarima_test_forecast
#making the test forecast series into dataframes
# sarima_test_forecast = pd.DataFrame(sarima_test_forecast,index= test.index)
# sarima_test_stderror = pd.DataFrame(sarima_test_stderror,index= test.index)
# sarima_test_confidence_int = pd.DataFrame(sarima_test_confidence_int,index= test.index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-154-8c3c69d43949> in <module>()
#       1 #forecasting values for the test dataset
# ----> 2 sarima_test_forecast , sarima_test_stderror, sarima_test_confidence_int = model_sarima.predict(steps=160,alpha=0.05)
#       3
#       4
#       5 sarima_test_forecast
#
# ValueError: too many values to unpack (expected 3)
